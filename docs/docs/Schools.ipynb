# %%
# %load_ext autoreload
# %autoreload 2
import wombat
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
w = wombat.Wombat()
w.set_city("Brisbane")
# Out:
# Setting: Brisbane

# %%
w.Schools.load()

# %%
w.Schools.df_acara.head()
# Out:
#    Calendar Year  ACARA SML ID  Location AGE ID  School AGE ID  \
# 0           2021         40000          40003.0            3.0
# 1           2021         40001          40004.0            4.0
# 2           2021         40002          40005.0            5.0
# 3           2021         40003          40007.0            7.0
# 4           2021         40004          40009.0            9.0
#
#                                 School Name        Suburb State  Postcode  \
# 0            Corpus Christi Catholic School     Bellerive   TAS      7018
# 1                              Fahan School     Sandy Bay   TAS      7005
# 2                  Geneva Christian College       Latrobe   TAS      7307
# 3               Holy Rosary Catholic School     Claremont   TAS      7011
# 4  Immaculate Heart of Mary Catholic School  Lenah Valley   TAS      7008
#
#   School Sector School Type  ... Non-Teaching Staff  \
# 0      Catholic     Primary  ...               19.0
# ...

# %%
w.Schools.df_schools.head()
# Out:
#    Calendar Year  ACARA SML ID  Location AGE ID  School AGE ID  \
# 0           2021         40000          40003.0            3.0
# 1           2021         40001          40004.0            4.0
# 2           2021         40002          40005.0            5.0
# 3           2021         40003          40007.0            7.0
# 4           2021         40004          40009.0            9.0
#
#                                 School Name        Suburb State  Postcode  \
# 0            Corpus Christi Catholic School     BELLERIVE   TAS      7018
# 1                              Fahan School     SANDY BAY   TAS      7005
# 2                  Geneva Christian College       LATROBE   TAS      7307
# 3               Holy Rosary Catholic School     CLAREMONT   TAS      7011
# 4  Immaculate Heart of Mary Catholic School  LENAH VALLEY   TAS      7008
#
#   School Sector School Type  ... Statistical Area 3 Statistical Area 3 Name  \
# ...

# %%
w.Schools.df
# Out:
#                                            School Name            Suburb  \
# ACARA SML ID
# 40000                   Corpus Christi Catholic School         BELLERIVE
# 40001                                     Fahan School         SANDY BAY
# 40002                         Geneva Christian College           LATROBE
# 40003                      Holy Rosary Catholic School         CLAREMONT
# 40004         Immaculate Heart of Mary Catholic School      LENAH VALLEY
# ...                                                ...               ...
# 53049           Ming-De International School Toowoomba         WESTBROOK
# 53050                    The Village School Gold Coast       COOLANGATTA
# 53055                   Secondary College of Languages        PARRAMATTA
# 53057           Nawarddeken Academy Mamadawerre School  West Arnhem Land
# 53058               Nawarddeken Academy Manmoyi School  West Arnhem Land
#
# ...

# %%
w.add_schools(junior_catchment=False,
              senior_catchment=False,
              primary_catchment=False,
              radius=20) # km from CBD
w
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
